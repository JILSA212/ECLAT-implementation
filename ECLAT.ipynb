# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/ML_project/data.csv", encoding="cp1252")
df
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 7 columns]

# %%
df.dropna()
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df["Description"].unique().shape
# Out:
# (4224,)

# %%
df = df[["InvoiceNo", "Description"]]
df["InvoiceNo"] = df["InvoiceNo"].astype("str")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
itemset = {}
temp = []

#print(list(df.loc[df["Description"] == "SET OF 6 T-LIGHTS SNOWMEN" ,"InvoiceNo"]))
unique_items = df["Description"].unique()

for i in unique_items:
#for k in range(0,1):
  #temp = []
  #temp.append(df.loc[df["Description"] == i ,"InvoiceNo"])
  #print(temp)
  itemset[i]=list(df.loc[df["Description"] == i ,"InvoiceNo"])

print(itemset)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
count_items = {}

for i in itemset.keys():
  count_items[i] = len(itemset[i])

print(count_items)
print(len(count_items))
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 2369, 'WHITE METAL LANTERN': 328, 'CREAM CUPID HEARTS COAT HANGER': 293, 'KNITTED UNION FLAG HOT WATER BOTTLE': 473, 'RED WOOLLY HOTTIE WHITE HEART.': 449, 'SET 7 BABUSHKA NESTING BOXES': 389, 'GLASS STAR FROSTED T-LIGHT HOLDER': 141, 'HAND WARMER UNION JACK': 515, 'HAND WARMER RED POLKA DOT': 18, 'ASSORTED COLOUR BIRD ORNAMENT': 1501, "POPPY'S PLAYHOUSE BEDROOM ": 436, "POPPY'S PLAYHOUSE KITCHEN": 451, 'FELTCRAFT PRINCESS CHARLOTTE DOLL': 469, 'IVORY KNITTED MUG COSY ': 111, 'BOX OF 6 ASSORTED COLOUR TEASPOONS': 213, 'BOX OF VINTAGE JIGSAW BLOCKS ': 243, 'BOX OF VINTAGE ALPHABET BLOCKS': 272, 'HOME BUILDING BLOCK WORD': 806, 'LOVE BUILDING BLOCK WORD': 656, 'RECIPE BOX WITH METAL HEART': 8, 'DOORMAT NEW ENGLAND': 608, 'JAM MAKING SET WITH JARS': 1229, 'RED COAT RACK PARIS FASHION': 114, 'YELLOW COAT RACK PARIS FASHION': 103, 'BLUE COAT RACK PARIS FASHION': 160, 'BATH BUILDING BLOCK WORD': 285, 'ALARM CLOCK BAKELIKE PINK': 810, 'ALARM CLOCK BAKE
# ...

# %%
threshold = 0.0005
min_sup = int(threshold * df.shape[0])
print(min_sup)

removing_ele = []

for i in count_items:
  if(count_items[i] < min_sup):
    removing_ele.append(i)
    
print(len(removing_ele))

for i in removing_ele:
  count_items.pop(i)
  itemset.pop(i)

single_items = count_items.copy()
print(len(count_items))
# Out:
# 270
# 3645
# 579

# %%
temp_dict = {}

for i in itemset.keys():
  for j in itemset.keys():
    if(i!=j):
      temp_set = ()
      temp_set = set(itemset[i]).intersection(set(itemset[j]))
      if(len(temp_set) > min_sup):
        count_items[str(i) + "," + str(j)] = len(temp_set)
        temp_dict[str(i) + "," + str(j)] = temp_set.copy()
      
itemset.update(temp_dict)

print(count_items)
print(len(count_items))
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 2369, 'WHITE METAL LANTERN': 328, 'CREAM CUPID HEARTS COAT HANGER': 293, 'KNITTED UNION FLAG HOT WATER BOTTLE': 473, 'RED WOOLLY HOTTIE WHITE HEART.': 449, 'SET 7 BABUSHKA NESTING BOXES': 389, 'HAND WARMER UNION JACK': 515, 'ASSORTED COLOUR BIRD ORNAMENT': 1501, "POPPY'S PLAYHOUSE BEDROOM ": 436, "POPPY'S PLAYHOUSE KITCHEN": 451, 'FELTCRAFT PRINCESS CHARLOTTE DOLL': 469, 'BOX OF VINTAGE ALPHABET BLOCKS': 272, 'HOME BUILDING BLOCK WORD': 806, 'LOVE BUILDING BLOCK WORD': 656, 'DOORMAT NEW ENGLAND': 608, 'JAM MAKING SET WITH JARS': 1229, 'BATH BUILDING BLOCK WORD': 285, 'ALARM CLOCK BAKELIKE PINK': 810, 'ALARM CLOCK BAKELIKE RED ': 1107, 'ALARM CLOCK BAKELIKE GREEN': 1024, 'VINTAGE HEADS AND TAILS CARD GAME ': 617, 'SET/2 RED RETROSPOT TEA TOWELS ': 403, 'ROUND SNACK BOXES SET OF4 WOODLAND ': 764, 'SPACEBOY LUNCH BOX ': 924, 'LUNCH BOX I LOVE LONDON': 750, 'CIRCUS PARADE LUNCH BOX ': 411, 'CHARLOTTE BAG DOLLY GIRL DESIGN': 425, 'RED TOADSTOOL LED N
# ...

# %%
temp_dict = {}

for i in itemset.keys():
  for j in itemset.keys():
    if("," in str(i) and "," not in str(j) and str(j) not in str(i)):
      temp_set = ()
      temp_set = set(itemset[i]).intersection(set(itemset[j]))
      if(len(temp_set) > min_sup):
        count_items[str(i) + "," + str(j)] = len(temp_set)
        temp_dict[str(i) + "," + str(j)] = temp_set.copy()
      
itemset.update(temp_dict)

print(count_items)
print(len(count_items))
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 2369, 'WHITE METAL LANTERN': 328, 'CREAM CUPID HEARTS COAT HANGER': 293, 'KNITTED UNION FLAG HOT WATER BOTTLE': 473, 'RED WOOLLY HOTTIE WHITE HEART.': 449, 'SET 7 BABUSHKA NESTING BOXES': 389, 'HAND WARMER UNION JACK': 515, 'ASSORTED COLOUR BIRD ORNAMENT': 1501, "POPPY'S PLAYHOUSE BEDROOM ": 436, "POPPY'S PLAYHOUSE KITCHEN": 451, 'FELTCRAFT PRINCESS CHARLOTTE DOLL': 469, 'BOX OF VINTAGE ALPHABET BLOCKS': 272, 'HOME BUILDING BLOCK WORD': 806, 'LOVE BUILDING BLOCK WORD': 656, 'DOORMAT NEW ENGLAND': 608, 'JAM MAKING SET WITH JARS': 1229, 'BATH BUILDING BLOCK WORD': 285, 'ALARM CLOCK BAKELIKE PINK': 810, 'ALARM CLOCK BAKELIKE RED ': 1107, 'ALARM CLOCK BAKELIKE GREEN': 1024, 'VINTAGE HEADS AND TAILS CARD GAME ': 617, 'SET/2 RED RETROSPOT TEA TOWELS ': 403, 'ROUND SNACK BOXES SET OF4 WOODLAND ': 764, 'SPACEBOY LUNCH BOX ': 924, 'LUNCH BOX I LOVE LONDON': 750, 'CIRCUS PARADE LUNCH BOX ': 411, 'CHARLOTTE BAG DOLLY GIRL DESIGN': 425, 'RED TOADSTOOL LED N
# ...

# %%
temp_dict = {}

for i in itemset.keys():
  for j in itemset.keys():
    if(str(i).count(",")==2 and "," not in str(j) and str(j) not in str(i)):
      temp_set = ()
      temp_set = set(itemset[i]).intersection(set(itemset[j]))
      if(len(temp_set) > min_sup):
        count_items[str(i) + "," + str(j)] = len(temp_set)
        temp_dict[str(i) + "," + str(j)] = temp_set.copy()
      
itemset.update(temp_dict)

print(count_items)
print(len(count_items))
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 2369, 'WHITE METAL LANTERN': 328, 'CREAM CUPID HEARTS COAT HANGER': 293, 'KNITTED UNION FLAG HOT WATER BOTTLE': 473, 'RED WOOLLY HOTTIE WHITE HEART.': 449, 'SET 7 BABUSHKA NESTING BOXES': 389, 'HAND WARMER UNION JACK': 515, 'ASSORTED COLOUR BIRD ORNAMENT': 1501, "POPPY'S PLAYHOUSE BEDROOM ": 436, "POPPY'S PLAYHOUSE KITCHEN": 451, 'FELTCRAFT PRINCESS CHARLOTTE DOLL': 469, 'BOX OF VINTAGE ALPHABET BLOCKS': 272, 'HOME BUILDING BLOCK WORD': 806, 'LOVE BUILDING BLOCK WORD': 656, 'DOORMAT NEW ENGLAND': 608, 'JAM MAKING SET WITH JARS': 1229, 'BATH BUILDING BLOCK WORD': 285, 'ALARM CLOCK BAKELIKE PINK': 810, 'ALARM CLOCK BAKELIKE RED ': 1107, 'ALARM CLOCK BAKELIKE GREEN': 1024, 'VINTAGE HEADS AND TAILS CARD GAME ': 617, 'SET/2 RED RETROSPOT TEA TOWELS ': 403, 'ROUND SNACK BOXES SET OF4 WOODLAND ': 764, 'SPACEBOY LUNCH BOX ': 924, 'LUNCH BOX I LOVE LONDON': 750, 'CIRCUS PARADE LUNCH BOX ': 411, 'CHARLOTTE BAG DOLLY GIRL DESIGN': 425, 'RED TOADSTOOL LED N
# ...

# %%
for i in single_items:
  count_items.pop(i)

# %%
new_df = pd.DataFrame.from_dict(count_items, orient='index')
new_df.to_csv("new_data.csv")
