# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/ML_project/new_data (6).csv")
df
# Out:
#                                              Unnamed: 0    0
# 0     WHITE HANGING HEART T-LIGHT HOLDER,ASSORTED CO...  323
# 1     WHITE HANGING HEART T-LIGHT HOLDER,WOODEN PICT...  410
# 2     WHITE HANGING HEART T-LIGHT HOLDER,WOODEN FRAM...  341
# 3     WHITE HANGING HEART T-LIGHT HOLDER,RED HANGING...  500
# 4     WHITE HANGING HEART T-LIGHT HOLDER,LUNCH BAG R...  332
# ...                                                 ...  ...
# 1013  PINK REGENCY TEACUP AND SAUCER,REGENCY CAKESTA...  303
# 1014  PINK REGENCY TEACUP AND SAUCER,ROSES REGENCY T...  303
# 1015  PINK REGENCY TEACUP AND SAUCER,ROSES REGENCY T...  303
# 1016  PINK REGENCY TEACUP AND SAUCER,GREEN REGENCY T...  303
# 1017  PINK REGENCY TEACUP AND SAUCER,GREEN REGENCY T...  303
#
# [1018 rows x 2 columns]

# %%
items = list(df["Unnamed: 0"].copy())
items
# Out:
# ['WHITE HANGING HEART T-LIGHT HOLDER,ASSORTED COLOUR BIRD ORNAMENT',
#  'WHITE HANGING HEART T-LIGHT HOLDER,WOODEN PICTURE FRAME WHITE FINISH',
#  'WHITE HANGING HEART T-LIGHT HOLDER,WOODEN FRAME ANTIQUE WHITE ',
#  'WHITE HANGING HEART T-LIGHT HOLDER,RED HANGING HEART T-LIGHT HOLDER',
#  'WHITE HANGING HEART T-LIGHT HOLDER,LUNCH BAG RED RETROSPOT',
#  'WHITE HANGING HEART T-LIGHT HOLDER,JUMBO STORAGE BAG SUKI',
#  'WHITE HANGING HEART T-LIGHT HOLDER,JUMBO SHOPPER VINTAGE RED PAISLEY',
#  'WHITE HANGING HEART T-LIGHT HOLDER,NATURAL SLATE HEART CHALKBOARD ',
#  'WHITE HANGING HEART T-LIGHT HOLDER,HEART OF WICKER SMALL',
#  'WHITE HANGING HEART T-LIGHT HOLDER,HEART OF WICKER LARGE',
#  'WHITE HANGING HEART T-LIGHT HOLDER,JUMBO BAG RED RETROSPOT',
#  'WHITE HANGING HEART T-LIGHT HOLDER,CANDLEHOLDER PINK HANGING HEART',
#  'WHITE HANGING HEART T-LIGHT HOLDER,VICTORIAN GLASS HANGING T-LIGHT',
#  'WHITE HANGING HEART T-LIGHT HOLDER,REGENCY CAKESTAND 3 TIER',
# ...

# %%
recommendation = {}

for i in items:
  temp = list(i.split(","))
  temp_value = temp[-1]
  temp_key = list(temp[:-1])
  recommendation[str(temp_key)] = temp_value

print(recommendation)
# Out:
# {"['WHITE HANGING HEART T-LIGHT HOLDER']": 'SET OF 3 CAKE TINS PANTRY DESIGN ', "['ASSORTED COLOUR BIRD ORNAMENT']": 'WHITE HANGING HEART T-LIGHT HOLDER', '["POPPY\'S PLAYHOUSE BEDROOM "]': "POPPY'S PLAYHOUSE KITCHEN", '["POPPY\'S PLAYHOUSE KITCHEN"]': "POPPY'S PLAYHOUSE BEDROOM ", "['HOME BUILDING BLOCK WORD']": 'LOVE BUILDING BLOCK WORD', "['LOVE BUILDING BLOCK WORD']": 'HOME BUILDING BLOCK WORD', "['JAM MAKING SET WITH JARS']": 'SET OF 4 PANTRY JELLY MOULDS', "['ALARM CLOCK BAKELIKE PINK']": 'ALARM CLOCK BAKELIKE IVORY', "['ALARM CLOCK BAKELIKE RED ']": 'ALARM CLOCK BAKELIKE CHOCOLATE', "['ALARM CLOCK BAKELIKE GREEN']": 'ALARM CLOCK BAKELIKE CHOCOLATE', "['VINTAGE HEADS AND TAILS CARD GAME ']": 'VINTAGE SNAP CARDS', "['ROUND SNACK BOXES SET OF4 WOODLAND ']": 'ROUND SNACK BOXES SET OF 4 FRUITS ', "['SPACEBOY LUNCH BOX ']": 'DOLLY GIRL LUNCH BOX', "['RED TOADSTOOL LED NIGHT LIGHT']": 'DOTCOM POSTAGE', '["PAPER CHAIN KIT 50\'S CHRISTMAS "]': '60 CAKE CASES VINTAGE CHRISTMAS', "['WOOD
# ...

# %%
input_item = ""
input_list = []

while(input_item.lower() != "quit"):
  recommend_list = []
  input_item = input()
  if(input_item.lower() == "quit"):
    print("Thank you")
    break
  input_list.append(input_item)
  try:
    for i in recommendation.keys():
      if(all(j in i for j in input_list)):
        recommend_list.append(recommendation[i])
    if(len(recommend_list)==0):
      print("No recommendation")
      input_list = []
    else:
      print("Recommendations:")
      for i in set(recommend_list):
        print(i)
  except(e):
    print("Exception occured",e)
# Out:
# quit
# Thank you
